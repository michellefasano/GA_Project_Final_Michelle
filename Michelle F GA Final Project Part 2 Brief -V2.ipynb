# %%
import matplotlib.pyplot as plt

% matplotlib inline
import pandas as pd
import numpy as np

# Read the data into a DataFrame
path = 'skill_and_wages4.csv'
skills = pd.read_csv(path)

# %%
skills.head()
skills.dtypes
#check out data
#median annual wage is not a float, will need to change this
# Out:
# SOC                                      object
# occupation_cat                           object
# line_item                                object
# employment_2016                         float64
# employment_2026                         float64
# employment_change_2016-26_#             float64
# employment_change_2016-26_%             float64
# percent_self_employed_2016               object
# occupational_openings_2016-26_annual    float64
# wage                                     object
# reading_comprehension                   float64
# active_listening                        float64
# writing                                 float64
# speaking                                float64
# mathematics                             float64
# science                                 float64
# critical_thinking                       float64
# active_learning                         float64
# learning_strategies                     float64
# monitoring                              float64
# social_perceptiveness                   float64
# coordination                            float64
# persuasion                              float64
# negotiation                             float64
# instructing                             float64
# service_orientation                     float64
# complex_problem_solving                 float64
# operations_analysis                     float64
# technology_design                       float64
# equipment_selection                     float64
# installation                            float64
# programming                             float64
# operation_monitoring                    float64
# operation_and_control                   float64
# equipment_maintenance                   float64
# troubleshooting                         float64
# repairing                               float64
# quality_control_analysis                float64
# judgment_and_decision_making            float64
# systems_analysis                        float64
# systems_evaluation                      float64
# time_management                         float64
# management_of_financial_resources       float64
# management_of_material_resources        float64
# management_of_personnel_resources       float64
# dtype: object

# %%
wage = skills.loc[:,'wage']

#tried wage.replace(['>=$208,000'],['208000'],inplace=True)
#then wage.astype('float64',errors='ignore')
#this still wouldn't go to numeric - so examined which are non numeric

# %%
skills.loc[:,'wage']= wage
skills.head()
# Out:
#        SOC                                 occupation_cat  line_item  \
# 0  00-0000                         Total, all occupations    Summary
# 1  11-0000                         Management occupations    Summary
# 2  11-1000                         Management occupations    Summary
# 3  43-9061  Office and administrative support occupations  Line item
# 4  51-2092                         Production occupations  Line item
#
#    employment_2016  employment_2026  employment_change_2016-26_#  \
# 0         156063.8         167582.3                      11518.6
# 1           9533.1          10411.5                        878.3
# 2           2627.5           2826.6                        199.1
# 3           3117.7           3085.7                        -32.1
# 4           1130.9            987.9                       -143.0
#
#    employment_change_2016-26_% percent_self_employed_2016  \
# 0                          7.4                        6.1
# 1                          9.2                       19.8
# 2                          7.6                        3.2
# 3                         -1.0                        0.4
# 4                        -12.6                        1.4
#
#    occupational_openings_2016-26_annual    wage  \
# 0                               18740.3   37040
# 1                                 851.2  100790
# 2                                 235.3  102320
# 3                                 356.2   30580
# 4                                 107.7   30060
#
#                  ...                  troubleshooting  repairing  \
# 0                ...                             0.00        0.0
# 1                ...                             0.00        0.0
# 2                ...                             0.00        0.0
# 3                ...                             0.12        0.0
# 4                ...                             2.00        1.5
#
#    quality_control_analysis  judgment_and_decision_making  systems_analysis  \
# 0                      0.00                          0.00              0.00
# 1                      0.00                          0.00              0.00
# 2                      0.00                          0.00              0.00
# 3                      0.50                          2.12              1.88
# 4                      2.75                          2.62              1.88
#
#    systems_evaluation  time_management  management_of_financial_resources  \
# 0                0.00             0.00                               0.00
# 1                0.00             0.00                               0.00
# 2                0.00             0.00                               0.00
# 3                1.38             2.75                               1.38
# 4                1.75             2.50                               0.62
#
#    management_of_material_resources  management_of_personnel_resources
# 0                              0.00                               0.00
# 1                              0.00                               0.00
# 2                              0.00                               0.00
# 3                              1.62                               2.25
# 4                              0.75                               2.38
#
# [5 rows x 45 columns]

# %%
skills.nunique()
skills.describe()
# Out:
#        employment_2016  employment_2026  employment_change_2016-26_#  \
# count      1091.000000      1091.000000                  1091.000000
# mean        634.254629       680.940147                    46.687443
# std        4928.258291      5286.516860                   369.648647
# min           0.600000         0.300000                  -385.300000
# 25%          24.550000        25.400000                     0.400000
# 50%          82.200000        86.900000                     4.300000
# 75%         308.800000       328.000000                    23.050000
# max      156063.800000    167582.300000                 11518.600000
#
#        employment_change_2016-26_%  occupational_openings_2016-26_annual  \
# count                  1091.000000                           1091.000000
# mean                      6.222915                             76.215032
# std                      10.751356                            596.617884
# min                     -78.600000                              0.000000
# 25%                       2.500000                              2.400000
# 50%                       7.400000                              8.700000
# 75%                      10.800000                             31.650000
# max                     105.300000                          18740.300000
#
#        reading_comprehension  active_listening      writing     speaking  \
# count            1091.000000       1091.000000  1091.000000  1091.000000
# mean                2.502899          2.443517     2.260736     2.381562
# std                 1.761007          1.667683     1.627608     1.652471
# min                 0.000000          0.000000     0.000000     0.000000
# 25%                 0.000000          0.000000     0.000000     0.000000
# 50%                 3.000000          3.000000     2.750000     2.880000
# 75%                 4.000000          3.880000     3.605000     3.771667
# max                 6.000000          5.880000     5.250000     5.380000
#
#        mathematics                ...                  troubleshooting  \
# count  1091.000000                ...                      1091.000000
# mean      1.729506                ...                         1.109887
# std       1.346378                ...                         1.204181
# min       0.000000                ...                         0.000000
# 25%       0.000000                ...                         0.000000
# 50%       2.000000                ...                         0.750000
# 75%       2.750000                ...                         2.120000
# max       6.120000                ...                         4.250000
#
#          repairing  quality_control_analysis  judgment_and_decision_making  \
# count  1091.000000               1091.000000                   1091.000000
# mean      0.738985                  1.528837                      2.203351
# std       1.160860                  1.279708                      1.520515
# min       0.000000                  0.000000                      0.000000
# 25%       0.000000                  0.000000                      0.000000
# 50%       0.000000                  1.620000                      2.750000
# 75%       1.380000                  2.750000                      3.380000
# max       4.250000                  4.000000                      5.000000
#
#        systems_analysis  systems_evaluation  time_management  \
# count       1091.000000         1091.000000      1091.000000
# mean           1.774916            1.762187         2.119323
# std            1.340013            1.354006         1.432127
# min            0.000000            0.000000         0.000000
# 25%            0.000000            0.000000         0.000000
# 50%            2.000000            2.000000         2.750000
# 75%            2.948333            3.000000         3.120000
# max            4.630000            4.880000         4.380000
#
#        management_of_financial_resources  management_of_material_resources  \
# count                        1091.000000                       1091.000000
# mean                            0.893250                          1.003242
# std                             0.954943                          0.933380
# min                             0.000000                          0.000000
# 25%                             0.000000                          0.000000
# 50%                             0.750000                          0.880000
# 75%                             1.380000                          1.620000
# max                             4.440000                          4.000000
#
#        management_of_personnel_resources
# count                        1091.000000
# mean                            1.792733
# std                             1.295030
# min                             0.000000
# 25%                             0.000000
# 50%                             2.120000
# 75%                             2.880000
# max                             4.620000
#
# [8 rows x 40 columns]

# %%
#explore which are non numeric

wage_not_num = skills.loc[:,'wage'].str.isnumeric() ==False

skills.loc[wage_not_num,:]

#its only a few rows....going to just remove
# Out:
#          SOC                                     occupation_cat  line_item  \
# 191  27-2011  Arts, design, entertainment, sports, and media...  Line item
# 364  27-2040  Arts, design, entertainment, sports, and media...    Summary
# 406  29-1060  Healthcare practitioners and technical occupat...    Summary
# 587  27-2099  Arts, design, entertainment, sports, and media...  Line item
# 677  27-2042  Arts, design, entertainment, sports, and media...  Line item
# 750  29-1067  Healthcare practitioners and technical occupat...  Line item
# 786  29-1061  Healthcare practitioners and technical occupat...  Line item
# 825  29-1064  Healthcare practitioners and technical occupat...  Line item
# 904  27-2031  Arts, design, entertainment, sports, and media...  Line item
# 988  29-1022  Healthcare practitioners and technical occupat...  Line item
# 992  29-1023  Healthcare practitioners and technical occupat...  Line item
#
#      employment_2016  employment_2026  employment_change_2016-26_#  \
# 191             63.8             71.3                          7.5
# 364            247.3            263.2                         15.9
# 406            713.8            820.3                        106.5
# 587             26.7             28.9                          2.1
# 677            172.4            183.8                         11.3
# 750             45.0             52.6                          7.6
# 786             33.0             38.9                          5.9
# 825             21.7             25.5                          3.9
# 904             13.5             14.1                          0.7
# 988              6.8              7.9                          1.2
# 992              6.6              7.7                          1.1
#
#      employment_change_2016-26_% percent_self_employed_2016  \
# 191                         11.7                       25.8
# 364                          6.4                       32.4
# 406                         14.9                        6.7
# 587                          8.0                       50.2
# 677                          6.6                       35.3
# 750                         16.8                        7.6
# 786                         17.8                        7.7
# 825                         17.9                        7.6
# 904                          5.0                       26.8
# 988                         17.2                       19.8
# 992                         17.3                       19.9
#
#      occupational_openings_2016-26_annual        wage  \
# 191                                   7.4           —
# 364                                  25.7           —
# 406                                  30.4  >=$208,000
# 587                                   3.2           —
# 677                                  18.0           —
# 750                                   2.0  >=$208,000
# 786                                   1.5  >=$208,000
# 825                                   1.0  >=$208,000
# 904                                   1.9           —
# 988                                   0.3  >=$208,000
# 992                                   0.3  >=$208,000
#
#                    ...                  troubleshooting  repairing  \
# 191                ...                             0.00       0.00
# 364                ...                             0.00       0.00
# 406                ...                             0.00       0.00
# 587                ...                             0.00       0.00
# 677                ...                             0.44       0.19
# 750                ...                             1.50       0.00
# 786                ...                             2.25       0.00
# 825                ...                             0.25       0.00
# 904                ...                             0.00       0.00
# 988                ...                             1.50       1.25
# 992                ...                             1.12       0.00
#
#      quality_control_analysis  judgment_and_decision_making  systems_analysis  \
# 191                     0.000                          3.00             1.620
# 364                     0.000                          0.00             0.000
# 406                     0.000                          0.00             0.000
# 587                     0.000                          0.00             0.000
# 677                     1.065                          2.81             2.065
# 750                     2.620                          4.88             3.380
# 786                     2.620                          4.25             3.250
# 825                     1.000                          4.38             3.120
# 904                     0.120                          2.38             2.250
# 988                     2.620                          4.12             3.250
# 992                     2.120                          3.75             3.000
#
#      systems_evaluation  time_management  management_of_financial_resources  \
# 191               1.620            3.000                              0.000
# 364               0.000            0.000                              0.000
# 406               0.000            0.000                              0.000
# 587               0.000            0.000                              0.000
# 677               2.125            2.625                              0.875
# 750               3.500            3.880                              1.880
# 786               3.250            4.000                              2.250
# 825               3.000            3.880                              1.750
# 904               1.880            2.500                              0.000
# 988               3.500            3.250                              1.500
# 992               2.880            4.000                              1.500
#
#      management_of_material_resources  management_of_personnel_resources
# 191                              0.00                              2.380
# 364                              0.00                              0.000
# 406                              0.00                              0.000
# 587                              0.00                              0.000
# 677                              1.00                              2.185
# 750                              2.25                              3.620
# 786                              2.25                              3.500
# 825                              2.00                              3.500
# 904                              0.00                              2.380
# 988                              1.50                              3.120
# 992                              1.88                              3.250
#
# [11 rows x 45 columns]

# %%
wage_num = skills.loc[:,'wage'].str.isnumeric()

skills = skills.loc[wage_num,:]

# %%
skills.describe(include= ['object'])

skills.shape

#1091 > 1080 so these rows were indeed removed
# Out:
# (1080, 45)

# %%
skills.wage = pd.to_numeric(skills['wage'])
#yay! wage is now numeric, might have been able to use this way all along

skills.dtypes
# Out:
# SOC                                      object
# occupation_cat                           object
# line_item                                object
# employment_2016                         float64
# employment_2026                         float64
# employment_change_2016-26_#             float64
# employment_change_2016-26_%             float64
# percent_self_employed_2016               object
# occupational_openings_2016-26_annual    float64
# wage                                      int64
# reading_comprehension                   float64
# active_listening                        float64
# writing                                 float64
# speaking                                float64
# mathematics                             float64
# science                                 float64
# critical_thinking                       float64
# active_learning                         float64
# learning_strategies                     float64
# monitoring                              float64
# social_perceptiveness                   float64
# coordination                            float64
# persuasion                              float64
# negotiation                             float64
# instructing                             float64
# service_orientation                     float64
# complex_problem_solving                 float64
# operations_analysis                     float64
# technology_design                       float64
# equipment_selection                     float64
# installation                            float64
# programming                             float64
# operation_monitoring                    float64
# operation_and_control                   float64
# equipment_maintenance                   float64
# troubleshooting                         float64
# repairing                               float64
# quality_control_analysis                float64
# judgment_and_decision_making            float64
# systems_analysis                        float64
# systems_evaluation                      float64
# time_management                         float64
# management_of_financial_resources       float64
# management_of_material_resources        float64
# management_of_personnel_resources       float64
# dtype: object

# %%
fig, ax = plt.subplots()
skills.plot(kind='scatter',x='active_listening',y='wage',ax=ax);
#as an example, active listening has a slight correlation with wage

fig, ax = plt.subplots()

skills.loc[:,'wage'].hist(bins=15,ax=ax);

# %%
axes = pd.plotting.scatter_matrix(skills, figsize=(15,15));

#would like to see this bigger to help me choose which skills are most correlated

# %%
skills.isnull().sum()
#no null values so that is good
# Out:
# SOC                                     0
# occupation_cat                          0
# line_item                               0
# employment_2016                         0
# employment_2026                         0
# employment_change_2016-26_#             0
# employment_change_2016-26_%             0
# percent_self_employed_2016              0
# occupational_openings_2016-26_annual    0
# wage                                    0
# reading_comprehension                   0
# active_listening                        0
# writing                                 0
# speaking                                0
# mathematics                             0
# science                                 0
# critical_thinking                       0
# active_learning                         0
# learning_strategies                     0
# monitoring                              0
# social_perceptiveness                   0
# coordination                            0
# persuasion                              0
# negotiation                             0
# instructing                             0
# service_orientation                     0
# complex_problem_solving                 0
# operations_analysis                     0
# technology_design                       0
# equipment_selection                     0
# installation                            0
# programming                             0
# operation_monitoring                    0
# operation_and_control                   0
# equipment_maintenance                   0
# troubleshooting                         0
# repairing                               0
# quality_control_analysis                0
# judgment_and_decision_making            0
# systems_analysis                        0
# systems_evaluation                      0
# time_management                         0
# management_of_financial_resources       0
# management_of_material_resources        0
# management_of_personnel_resources       0
# dtype: int64

# %%
#next steps:

#determine which skills are most correlated with wage, may have to combine skills to make new features
#perhaps take out wage bands that are not relevant to this analysis (over 80k)
#still a wide range of wage values for when a given skill is zero - this will throw off data, need to firgure out how to deal with this
#could also look at abilities or knowledge instead of skills
